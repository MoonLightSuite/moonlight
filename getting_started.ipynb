# %%
import os
#os.environ['JAVA_HOME'] = "/home/ssilvetti/Java/jdk1.8.0_172/"
#os.environ['JAVA_HOME'] = "/Library/Java/JavaVirtualMachines/jdk-11.0.5.jdk/Contents/Home"
from moonlight import *
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (15,10)
# Out:
# ---------------------------------------------------------------------------
# SystemError                               Traceback (most recent call last)
# <ipython-input-1-e955b05566e2> in <module>
#       2 #os.environ['JAVA_HOME'] = "/home/ssilvetti/Java/jdk1.8.0_172/"
#       3 #os.environ['JAVA_HOME'] = "/Library/Java/JavaVirtualMachines/jdk-11.0.5.jdk/Contents/Home"
# ----> 4 from moonlight import *
#       5 import numpy as np
#       6 import matplotlib.pyplot as plt
#
# ~/git/MoonLight/distribution_files/python/moonlight.py in <module>
#       1 import jnius_config
#       2 jnius_config.set_classpath('./jar/moonlight.jar')
# ----> 3 from jnius import autoclass
#       4
#       5 class MoonlightScript:
#
# ~/miniconda3/lib/python3.6/site-packages/jnius/__init__.py in <module>
#      11
#      12 from .jnius import *  # noqa
# ---> 13 from .reflect import *  # noqa
#      14
#      15 # XXX monkey patch methods that cannot be in cython.
#
# ~/miniconda3/lib/python3.6/site-packages/jnius/reflect.py in <module>
#      12
#      13
# ---> 14 class Class(with_metaclass(MetaJavaClass, JavaClass)):
#      15     __javaclass__ = 'java/lang/Class'
#      16
#
# ~/miniconda3/lib/python3.6/site-packages/six.py in __new__(cls, name, this_bases, d)
#     854             else:
#     855                 resolved_bases = bases
# --> 856             return meta(name, resolved_bases, d)
#     857
#     858         @classmethod
#
# jnius/jnius_export_class.pxi in jnius.MetaJavaClass.__new__()
#
# jnius/jnius_export_class.pxi in jnius.MetaJavaClass.resolve_class()
#
# jnius/jnius_env.pxi in jnius.get_jnienv()
#
# jnius/jnius_jvm_dlopen.pxi in jnius.get_platform_jnienv()
#
# jnius/jnius_jvm_dlopen.pxi in jnius.create_jnienv()
#
# SystemError: Error calling dlopen(b'/home/ssilvetti/miniconda3/jre/lib/amd64/server/libjvm.so': b'/home/ssilvetti/miniconda3/jre/lib/amd64/server/libjvm.so: cannot open shared object file: No such file or directory'

# %%
script = """
signal { real x; real y;}
domain boolean; 
formula future = globally [0, 0.2]  (x > y);
formula past = historically [0, 0.2]  (x > y);
"""
moonlightScript = ScriptLoader.loadFromText(script)

# %%
monitor = moonlightScript.getMonitor("future")
time =list(np.arange(0,10,0.05))
f1,f2 = np.sin(time),np.cos(time)
space = list(zip(f1,f2))
result = np.array(monitor.monitor(time,space))
plt.plot(time,f1)
plt.plot(time,f2)
plt.step(result[:,0],result[:,1])

# %%
monitor = moonlightScript.getMonitor("past")
time =list(np.arange(0,10,0.05))
f1,f2 = np.sin(time),np.cos(time)
space = list(zip(f1,f2))
result = np.array(monitor.monitor(time,space))
plt.plot(time,f1)
plt.plot(time,f2)
plt.step(result[:,0],result[:,1])

# %%
script = """
signal { real x}
domain boolean; 
formula future = globally [0, 0.2]  (x > 1);
"""
moonlightScript = ScriptLoader.loadFromText(script)

# %%
monitor = moonlightScript.getMonitor("future")
time =list(np.arange(0,10,0.05))
f1=np.sin(time)
space = [[x] for x in f1]
result =monitor.monitor(time,space)

# %%
result
# Out:
# [[0.0, -1.0], [9.950000000000001, -1.0]]
